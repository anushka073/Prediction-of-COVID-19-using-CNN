# %% [markdown]
# # 1) Importing Libraries

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D,Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 2) Cloning of Dataset

# %%
# CLONING THE DATASET FROM THE GITHUB REPOSITORY
# !git clone https://github.com/RishitToteja/Chext-X-ray-Images-Data-Set.git
# Out:
# Cloning into 'Chext-X-ray-Images-Data-Set'...
# remote: Enumerating objects: 2319, done.
# remote: Total 2319 (delta 0), reused 0 (delta 0), pack-reused 2319 (from 1)
# Receiving objects: 100% (2319/2319), 1.31 GiB | 38.83 MiB/s, done.
# Updating files: 100% (2296/2296), done.

# %%
import os

main_dir = "/content/Chext-X-ray-Images-Data-Set/DataSet/Data"

# SETTING TRAIN AND TEST DIRECTORY
train_dir = os.path.join(main_dir, "train")
test_dir = os.path.join(main_dir, "test")

#SETING DIRECTORY FOR COVID AND NORMAL IMAGES DIRECTORY
train_covid_dir = os.path.join(train_dir, "COVID19")
train_normal_dir = os.path.join(train_dir, "NORMAL")

test_covid_dir = os.path.join(test_dir, "COVID19")
test_normal_dir = os.path.join(test_dir, "NORMAL")

# %%
# MAKING SEPERATE FILES :
train_covid_names = os.listdir(train_covid_dir)
train_normal_names = os.listdir(train_normal_dir)

test_covid_names = os.listdir(test_covid_dir)
test_normal_names = os.listdir(test_normal_dir)

# %% [markdown]
# # 3) Data Visualization

# %%
import matplotlib.image as mpimg

rows = 4
columns = 4

fig = plt.gcf()
fig.set_size_inches(12,12)

covid_img = [os.path.join(train_covid_dir, filename) for filename in train_covid_names[0:8]]
normal_img = [os.path.join(train_normal_dir, filename) for filename in train_normal_names[0:8]]

print(covid_img)
print(normal_img)

merged_img = covid_img + normal_img

for i, img_path in enumerate(merged_img):
  title = img_path.split("/", 6)[6]
  plot = plt.subplot(rows, columns, i+1)
  plot.axis("Off")
  img = mpimg.imread(img_path)
  plot.set_title(title, fontsize = 11)
  plt.imshow(img, cmap= "gray")

plt.show()
# Out:
# ['/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(447).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID-19 (7).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(329).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID-19 (155).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(252).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(517).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(107).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(263).jpg']
# ['/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(885).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(371).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(315).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(1290).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(875).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(1123).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(1304).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(684).jpg']

# %% [markdown]
# # 4) Data Preprocessing and Augmentation

# %%
# CREATING TRAINING, TESTING AND VALIDATION BATCHES

dgen_train = ImageDataGenerator(rescale = 1./255,
                                validation_split = 0.2,
                                zoom_range = 0.2,
                                horizontal_flip = True)

dgen_validation = ImageDataGenerator(rescale = 1./255,
                                     )

dgen_test = ImageDataGenerator(rescale = 1./255,
                              )

train_generator = dgen_train.flow_from_directory(train_dir,
                                                 target_size = (150, 150),
                                                 subset = 'training',
                                                 batch_size = 32,
                                                 class_mode = 'binary')
validation_generator = dgen_train.flow_from_directory(train_dir,
                                                      target_size = (150, 150),
                                                      subset = "validation",
                                                      batch_size = 32,
                                                      class_mode = "binary")
test_generator = dgen_test.flow_from_directory(test_dir,
                                               target_size = (150, 150),
                                               batch_size = 32,
                                               class_mode = "binary")
# Out:
# Found 1449 images belonging to 2 classes.
# Found 362 images belonging to 2 classes.
# Found 484 images belonging to 2 classes.

# %%
print("Class Labels are: ", train_generator.class_indices)
print("Image shape is : ", train_generator.image_shape)
# Out:
# Class Labels are:  {'COVID19': 0, 'NORMAL': 1}
# Image shape is :  (150, 150, 3)

# %% [markdown]
# # 5) Building Convolutional Neural Network Model

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D

model = Sequential()

# 1) CONVOLUTIONAL LAYER - 1
model.add(Conv2D(32, (5,5), padding = "same", activation = "relu", input_shape = train_generator.image_shape))

# 2) POOLING LAYER - 1
model.add(MaxPooling2D(pool_size=(2,2)))

# 3) DROPOUT LAYER -2
model.add(Dropout(0.5))

# 4) CONVOLUTIONAL LAYER - 2
model.add(Conv2D(64, (5,5), padding = "same", activation = "relu"))

# 5) POOLING LAYER - 2
model.add(MaxPooling2D(pool_size=(2,2)))

# 6) DROPOUT LAYER - 2
model.add(Dropout(0.5))

# 7) FLATTENING LAYER TO 2D SHAPE
model.add(Flatten())

# 8) ADDING A DENSE LAYER
model.add(Dense(256, activation = 'relu'))

# 9 DROPOUT LAYER - 3
model.add(Dropout(0.5))

# 10) FINAL OUTPUT LAYER
model.add(Dense(1, activation = 'sigmoid'))

### PRINTING MODEL SUMMARY
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 150, 150, 32)   │         2,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 75, 75, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 75, 75, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 75, 75, 64)     │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 37, 37, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 37, 37, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 87616)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │    22,429,952 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,483,905 (85.77 MB)
#  Trainable params: 22,483,905 (85.77 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 6) Compiling and Training the Neural Network Model

# %%
# COMPILING THE MODEL

model.compile(Adam(learning_rate = 0.001), loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# TRAINING THE MODEL
history = model.fit(train_generator,
                    epochs = 35,
                    validation_data = validation_generator)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.6901 - loss: 2.2269 - val_accuracy: 0.8343 - val_loss: 0.5599
# Epoch 2/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 45s 958ms/step - accuracy: 0.8929 - loss: 0.2853 - val_accuracy: 0.9309 - val_loss: 0.2419
# Epoch 3/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 43s 943ms/step - accuracy: 0.9269 - loss: 0.1973 - val_accuracy: 0.9586 - val_loss: 0.1167
# Epoch 4/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 44s 972ms/step - accuracy: 0.9526 - loss: 0.1444 - val_accuracy: 0.9530 - val_loss: 0.1496
# Epoch 5/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 44s 951ms/step - accuracy: 0.9506 - loss: 0.1620 - val_accuracy: 0.9503 - val_loss: 0.1403
# Epoch 6/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 45s 981ms/step - accuracy: 0.9427 - loss: 0.1632 - val_accuracy: 0.9586 - val_loss: 0.1134
# Epoch 7/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 45s 989ms/step - accuracy: 0.9500 - loss: 0.1403 - val_accuracy: 0.9365 - val_loss: 0.1792
# Epoch 8/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 44s 948ms/step - accuracy: 0.9499 - loss: 0.1310 - val_accuracy: 0.9448 - val_loss: 0.1339
# Epoch 9/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.9649 - loss: 0.1113 - val_accuracy: 0.9503 - val_loss: 0.1455
# Epoch 10/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 45s 994ms/step - accuracy: 0.9450 - loss: 0.1252 - val_accuracy: 0.9641 - val_loss: 0.1210
# Epoch 11/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 43s 945ms/step - accuracy: 0.9712 - loss: 0.1029 - val_accuracy: 0.9613 - val_loss: 0.1075
# Epoch 12/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 44s 966ms/step - accuracy: 0.9543 - loss: 0.1191 - val_accuracy: 0.9503 - val_loss: 0.1194
# Epoch 13/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 43s 942ms/step - accuracy: 0.9703 - loss: 0.1051 - val_accuracy: 0.9586 - val_loss: 0.1053
# Epoch 14/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 45s 982ms/step - accuracy: 0.9661 - loss: 0.1064 - val_accuracy: 0.9530 - val_loss: 0.1251
# Epoch 15/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 43s 940ms/step - accuracy: 0.9583 - loss: 0.1304 - val_accuracy: 0.9724 - val_loss: 0.0846
# Epoch 16/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 44s 955ms/step - accuracy: 0.9736 - loss: 0.0884 - val_accuracy: 0.9696 - val_loss: 0.0704
# Epoch 17/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.9744 - loss: 0.0691 - val_accuracy: 0.9503 - val_loss: 0.1379
# Epoch 18/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 43s 942ms/step - accuracy: 0.9431 - loss: 0.1733 - val_accuracy: 0.9779 - val_loss: 0.0925
# Epoch 19/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 45s 988ms/step - accuracy: 0.9617 - loss: 0.1126 - val_accuracy: 0.9613 - val_loss: 0.1027
# Epoch 20/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.9669 - loss: 0.1215 - val_accuracy: 0.9834 - val_loss: 0.0683
# Epoch 21/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 43s 946ms/step - accuracy: 0.9765 - loss: 0.0774 - val_accuracy: 0.9779 - val_loss: 0.0899
# Epoch 22/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.9758 - loss: 0.0821 - val_accuracy: 0.9779 - val_loss: 0.0696
# Epoch 23/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 45s 977ms/step - accuracy: 0.9482 - loss: 0.1511 - val_accuracy: 0.9503 - val_loss: 0.1163
# Epoch 24/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 43s 920ms/step - accuracy: 0.9434 - loss: 0.1638 - val_accuracy: 0.9641 - val_loss: 0.0973
# Epoch 25/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 44s 962ms/step - accuracy: 0.9674 - loss: 0.0917 - val_accuracy: 0.9751 - val_loss: 0.0605
# Epoch 26/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 44s 950ms/step - accuracy: 0.9829 - loss: 0.0672 - val_accuracy: 0.9751 - val_loss: 0.0679
# Epoch 27/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 46s 981ms/step - accuracy: 0.9779 - loss: 0.0621 - val_accuracy: 0.9807 - val_loss: 0.0669
# Epoch 28/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 45s 974ms/step - accuracy: 0.9796 - loss: 0.0529 - val_accuracy: 0.9751 - val_loss: 0.0714
# Epoch 29/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 44s 966ms/step - accuracy: 0.9776 - loss: 0.0589 - val_accuracy: 0.9724 - val_loss: 0.0673
# Epoch 30/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 44s 965ms/step - accuracy: 0.9798 - loss: 0.0674 - val_accuracy: 0.9751 - val_loss: 0.0600
# Epoch 31/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 44s 964ms/step - accuracy: 0.9791 - loss: 0.0614 - val_accuracy: 0.9751 - val_loss: 0.0725
# Epoch 32/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 44s 967ms/step - accuracy: 0.9774 - loss: 0.0811 - val_accuracy: 0.9669 - val_loss: 0.0921
# Epoch 33/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 43s 935ms/step - accuracy: 0.9830 - loss: 0.0538 - val_accuracy: 0.9751 - val_loss: 0.0668
# Epoch 34/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 44s 958ms/step - accuracy: 0.9796 - loss: 0.0514 - val_accuracy: 0.9779 - val_loss: 0.0572
# Epoch 35/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.9900 - loss: 0.0387 - val_accuracy: 0.9696 - val_loss: 0.0701

# %% [markdown]
# # 7) Performing Evaluation

# %%
# KEYS OF HISTORY OBJECT
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# PLOT GRAPH BETWEEN TRAINING AND VALIDATION LOSS
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Training', 'Validation'])
plt.title("Training and validation losses")
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
# PLOT GRAPH BETWEEN TRAINING AND VALIDATION ACCURACY
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['Training', 'Validation'])
plt.title("Training and validation accuracy")
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
# GETTING TEST ACCURACY AND LOSS

test_loss, test_acc = model.evaluate(test_generator)
print("Test Set Loss : ", test_loss)
print("Test Set Accuracy : ", test_acc)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 626ms/step - accuracy: 0.9899 - loss: 0.0490
# Test Set Loss :  0.056316621601581573
# Test Set Accuracy :  0.9855371713638306

# %% [markdown]
# # 9) Prediction on New Data

# %%
from google.colab import files
from keras.preprocessing import image

uploaded = files.upload()

for filename in uploaded.keys():
  img_path = '/content/' + filename
  img = image.load_img(img_path, target_size = (150,150))
  images = image.img_to_array(img)
  images = np.expand_dims(images, axis = 0)
  prediction = model.predict(images)

  if prediction == 0:
    print("The report is COVID-19 Positive")
  else:
    print("The report is COVID-19 Negative")

# %%
model.save("model.h5")
